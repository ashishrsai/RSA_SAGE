# %%
##############################################################################
##Genrate private and public keys
##In order to genrate keys we need to genrate two large random primes with 50 bits each
##############################################################################
#p = random_prime(10^50-1,False,10^48) #We can use this p in order to generate new prime number 
#q = random_prime(10^50-1,False,10^48) #We can use this q in order to generate new prime number
p = 29927402397991286489627837734179186385188296382227 #Feeding in the values generated intially in order to decypt the message
q = 22953686867719691230002707821868552601124472329079 #Feeding in the values generated intially in order to decypt the message
print '----------------------------------------------------------------------------------------------------------------------'
print 'The generated Prime number p = ',p,' is a true prime ? Solution = ', is_prime(p)
print 'The generated Prime number p = ',p,' is a true prime ? Solution = ',is_prime(q)

#if condition to make sure we do not end up with same prime
if p !=q:
    n = p*q
#Now we have to calculate public key for that we need PHI 
pi = (p-1)*(q-1)
#e is the public key 
#e = 0
#This while loop is how we generate the coprime number uncommenting the following section would yeild in new value of e 
#while gcd(e,pi)!=1:
#    e=ZZ.random_element(pi)
e = 44295779445365649934766605049611153683595792133011 #Feeding in already generated values in order to decrypt.
##Now we have the public key and we need to calculate private key
d = lift(Mod(e,pi)^(-1))
print 'The value of N = ',n
print 'The value of e (Public Key) = ',e
print 'The value of d (Private Key) = ',d
print '----------------------------------------------------------------------------------------------------------------------'
##############################################################################
# Mr. Dylan has not obtained the Nobel Price for literature for nothing so we encrypt his famous lyrics of Like a rolling stone
##############################################################################
##Convert from string to numbers and back to numbers.
alphabet='0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz ,.?!:;-\'\"'
def string2number(string):
    M=0
    for i in range(len(string)):
        M = 100*M + alphabet.index(string[i])
    return M
def number2string(M):
    string=''
    while M > 0:
        i = M % 100
        M = (M-i)/100
        string = alphabet[i] + string
    return string
Str = "Once upon a time you dressed so fine Threw the bums a dime in your prime, didn't you? People call say 'beware doll, you're bound to fall' You thought they were all kidding you You used to laugh about Everybody that was hanging out Now you don't talk so loud Now you don't seem so proud About having to be scrounging your next meal How does it feel, how does it feel? To be without a home Like a complete unknown, like a rolling stone Ahh you've gone to the finest schools, alright Miss Lonely But you know you only used to get juiced in it Nobody's ever taught you how to live out on the street And now you're gonna have to get used to it You say you never compromise With the mystery tramp, but now you realize He's not selling any alibis As you stare into the vacuum of his eyes And say do you want to make a deal? How does it feel, how does it feel? To be on your own, with no direction home A complete unknown, like a rolling stone Ah you never turned around to see the frowns On the jugglers and"
convertedStr = string2number(Str)
m = convertedStr

## Split the numbers
result = []
def large_number_split(L, S):
    str = S.str() #alternative to str(S)
    length = len(str)
    remainder = length%L
    integer = length//L
    #print integer, remainder
    if remainder != 0:
        result.append(int(str[0:remainder]))
    for i in range(integer):
        sub_str = str[i*L+remainder:(i+1)*L+remainder]
        result.append(int(sub_str))
    #print result
large_number_split(40, m)

##Lets Encypt our message
enyMessage = []
print 'BEAWARE: Encrypted Message Ahead'
print '----------------------------------------------------------------------------------------------------------------------'
for i in range(40):    
    enyMessage.append(Integer(Mod(result[i],n)^e))
    print enyMessage[i]
print '----------------------------------------------------------------------------------------------------------------------'    
##############################################################################
#Time to decrypt
##############################################################################
